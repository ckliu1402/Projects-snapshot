# %%
import sys
sys.path.append("../src/models")
import datetime
from monte_carlo_stimulation import monte_carlo
from ipywidgets import interact, interactive

# %%
print ('Calculating....')
start = datetime.datetime(2019, 1, 1)

sim = monte_carlo(start)
sim.get_asset('1177.HK')

sim.brownian_motion(10000, 5)
print ('Finished!')
ha = sim.line_graph()
sim.VaR()
sim.key_stats(est_price_low = 10, est_price_high=12)
# Out:
# Calculating....
# Finished!
# Value at Risk:  1.4371999658410957
# #----------------------Stock Stats-------------------------#
# CAGR = 136.95999999999998%
# Annual Volatility = 44.57%
# Current Price = 11.48
#
#
# #----------------------Last Price Stats--------------------#
# Mean Price:  11.661775014100042
# Maximum Price:  14.659046493334596
# Minimum Price:  8.908834401083146
# Standard Deviation:  0.7394268514843224
# Price with 10% in 5 days below:  10.729986598391836
# Price with 10% in 5 days above:  12.61616279886572
#
#
# #----------------------Descriptive Stats-------------------#
# count    10000.000000
# mean        11.661775
# std          0.739464
# min          8.908834
# 25%         11.150818
# 50%         11.640011
# 75%         12.149367
# max         14.659046
# Name: 5, dtype: float64
#
#
# #----------------------Percentiles-------------------------#
# 5th Percentile:  10.483423849487856
# 50th Percentile:  11.640011412473243
# ...
